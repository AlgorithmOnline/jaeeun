# %%
mapsbuffer=[]
buffer=[0]*7
mapsbuffer.append(buffer)


for _ in range(5):
    a=[0]
    a+=list(input())
    a.append(0)
    mapsbuffer.append(a)
    
    
mapsbuffer.append(buffer)
# Out:
# YYYYY
# SYSYS
# YYYYY
# YSYYS
# YYYYY

# %%
mapsbuffer=[
 [ 'Y', 'Y', 'Y', 'Y', 'Y'],
 [ 'S', 'Y', 'S', 'Y', 'S'],
 [ 'Y', 'Y', 'Y', 'Y', 'Y'],
 [ 'Y', 'S', 'Y', 'Y', 'S'],
 [ 'Y', 'Y', 'Y', 'Y', 'Y'],]

# %%
s_where=[] # s좌표들 저장
y_where=[]
for i in range(5): # column
    for k in  range(5): # row
        if mapsbuffer[k][i] =='S':
            s_where.append([k,i])
        else:
            y_where.append([k,i])

# %%
import itertools
s_how=list(itertools.combinations(s_where,4))
y_how=list(itertools.combinations(y_where,3))

# %%
ans_list=[]
for y in y_how:
    for s in s_how:
        may= y+s
        if connectings(may):
            ans_list.append(may)
ans_list
# Out:
# [([0, 0], [3, 0], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4]),
#  ([0, 0], [3, 0], [2, 4], [1, 0], [3, 1], [1, 4], [3, 4]),
#  ([0, 0], [1, 1], [2, 4], [1, 0], [1, 2], [1, 4], [3, 4]),
#  ([0, 0], [2, 1], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4]),
#  ([0, 0], [2, 1], [2, 4], [1, 0], [3, 1], [1, 4], [3, 4]),
#  ([0, 0], [4, 1], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4]),
#  ([0, 0], [4, 1], [2, 4], [1, 0], [3, 1], [1, 4], [3, 4]),
#  ([0, 0], [0, 2], [2, 4], [1, 0], [1, 2], [1, 4], [3, 4]),
#  ([0, 0], [2, 2], [2, 4], [1, 0], [1, 2], [1, 4], [3, 4]),
#  ([0, 0], [3, 2], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4]),
#  ([0, 0], [3, 2], [2, 4], [1, 0], [3, 1], [1, 4], [3, 4]),
#  ([0, 0], [1, 3], [3, 3], [1, 0], [1, 2], [1, 4], [3, 4]),
#  ([0, 0], [1, 3], [2, 4], [1, 0], [1, 2], [1, 4], [3, 4]),
#  ([0, 0], [1, 3], [4, 4], [1, 0], [1, 2], [1, 4], [3, 4]),
#  ([2, 0], [3, 0], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4]),
#  ([2, 0], [3, 0], [2, 4], [1, 0], [3, 1], [1, 4], [3, 4]),
# ...

# %%
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-117-8e5a67e1ac11> in <module>()
# ----> 1 DFS_with_adj_list(data, data[0])
#
# <ipython-input-116-36c7e1b57205> in DFS_with_adj_list(graph, root)
#       8         if n not in visited:
#       9             visited.append(n)
# ---> 10             stack += graph[n] - set(visited)
#      11     return visited
#      12
#
# TypeError: tuple indices must be integers or slices, not list

# %%
data=list(data)

# %%
data
# Out:
# [[0, 0], [3, 0], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4]]

# %%
v
# Out:
# [0, 30, 13, 10, 31, 12, 14]

# %%
data=([0, 0], [3, 0], [1, 3], [1, 0], [3, 1], [1, 2], [1, 4])
data=list(map(lambda a:a[0]*10+a[1],data))
print(data)
def DFS_with_adj_list(graph, root):
    visited = []
    stack = [root]

    while stack:
        n = stack.pop()
        if n not in visited:
            visited.append(n)
            stack += graph[n] - set(visited)
    return visited
DFS_with_adj_list(data, data[0])
# Out:
# [0, 30, 13, 10, 31, 12, 14]
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-137-158d2cff220b> in <module>()
#      12             stack += graph[n] - set(visited)
#      13     return visited
# ---> 14 DFS_with_adj_list(data, data[0])
#
# <ipython-input-137-158d2cff220b> in DFS_with_adj_list(graph, root)
#      10         if n not in visited:
#      11             visited.append(n)
# ---> 12             stack += graph[n] - set(visited)
#      13     return visited
#      14 DFS_with_adj_list(data, data[0])
#
# TypeError: unsupported operand type(s) for -: 'int' and 'set'
